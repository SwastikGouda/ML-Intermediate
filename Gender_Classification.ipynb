# %%
import numpy as np
import pandas as pd
import chardet

# %%
with open('/content/Indian-Name.csv', 'rb') as f:
    result = chardet.detect(f.read())

# %%
df = pd.read_csv('/content/Indian-Name.csv', encoding=result['encoding'])

# %%
df1=pd.read_csv('/content/Gender_Data.csv')

# %%
s=[]
for i in df1['Gender']:
  if i==1:
    s.append(0)
  else:
    s.append(1)

# %%
df1

# %%
df1=df1[['Name','Target']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-4eaceac5237b> in <cell line: 1>()
# ----> 1 df1=df1[['Name','Target']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# ...

# %%
# 1-Male 0-Female

# %%
# Indian-Name.csv
X =list( df['Name'])

Y = list(df['Target'])

# %%
# Gender_Data.csv
X1 =list(df1['Name'])

Y1 = list(df1['Gender'])

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(analyzer='char')

# %%
X1=cv.fit_transform(X1).toarray()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X1, Y1, test_size=0.33, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e08817b12d3f> in <cell line: 3>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 x_train, x_test, y_train, y_test = train_test_split(X1, Y1, test_size=0.33, random_state=42)
#
# NameError: name 'X1' is not defined

# %% [markdown]
# Model Building

# %%
from tensorflow.keras import models
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from keras.layers import Embedding
from tensorflow.keras.layers import Dense, Dropout, Flatten, Input, LeakyReLU
from tensorflow.keras.layers import BatchNormalization, Activation, Conv2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, MaxPooling2D, Dense, Dropout
from tensorflow.keras.layers import LSTM

# %%
max_words = 1000

max_len = 26

LSTM_model = Sequential()

LSTM_model.add(Embedding(53925,40,input_length=26))

LSTM_model.add(Dropout(0.3))

LSTM_model.add(LSTM(100))

LSTM_model.add(Dropout(0.3))

LSTM_model.add(Dense(64,activation='relu'))

LSTM_model.add(Dropout(0.3))

LSTM_model.add(Dense(1,activation='sigmoid'))

LSTM_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

print(LSTM_model.summary())
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_7 (Embedding)     (None, 26, 40)            2157000
#
#  dropout_21 (Dropout)        (None, 26, 40)            0
#
#  lstm_7 (LSTM)               (None, 100)               56400
#
#  dropout_22 (Dropout)        (None, 100)               0
#
#  dense_14 (Dense)            (None, 64)                6464
#
#  dropout_23 (Dropout)        (None, 64)                0
#
#  dense_15 (Dense)            (None, 1)                 65
#
# ...
# Total params: 2219929 (8.47 MB)
# Trainable params: 2219929 (8.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
LSTM_model.fit(x_train,y_train,epochs=100,batch_size=64)
# Out:
# Epoch 1/100
# 566/566 [==============================] - 42s 69ms/step - loss: 0.6685 - accuracy: 0.5816
# Epoch 2/100
# 566/566 [==============================] - 38s 68ms/step - loss: 0.6426 - accuracy: 0.6252
# Epoch 3/100
# 566/566 [==============================] - 39s 69ms/step - loss: 0.6315 - accuracy: 0.6425
# Epoch 4/100
# 566/566 [==============================] - 39s 69ms/step - loss: 0.6209 - accuracy: 0.6548
# Epoch 5/100
# 566/566 [==============================] - 39s 70ms/step - loss: 0.6164 - accuracy: 0.6574
# Epoch 6/100
# 566/566 [==============================] - 39s 70ms/step - loss: 0.6121 - accuracy: 0.6617
# Epoch 7/100
# 566/566 [==============================] - 39s 70ms/step - loss: 0.6058 - accuracy: 0.6692
# Epoch 8/100
# 566/566 [==============================] - 40s 71ms/step - loss: 0.6009 - accuracy: 0.6738
# Epoch 9/100
# 566/566 [==============================] - 40s 71ms/step - loss: 0.5951 - accuracy: 0.6779
# Epoch 10/100
# ...

# %%
import pickle
with open('/content/LSTM_Gender-Prediction_model.pkl', 'rb') as file:
  LSTM_model= pickle.load(file)

# %%
def prediction(s):
  b=LSTM_model.predict([cv.transform([s]).toarray()])[0][0]

  if b >= 0.5:
    return 'Male'
  else:
    return'Female'

# %%
import pickle

pickle.dump(LSTM_model, open("LSTM_model.pkl", 'wb'))

# %%
prediction('')
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Male

# %%
dx=pd.read_csv('/content/Karyakarta-Zila-Core_Sangathan (13).csv')
# Out:
# <ipython-input-35-a1c73aa9a93b>:1: DtypeWarning: Columns (15,37,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   dx=pd.read_csv('/content/Karyakarta-Zila-Core_Sangathan (13).csv')

# %%
dx=dx[['Person Full Name','Person Gender']]

# %%
dx
# Out:
#           Person Full Name Person Gender
# 0      Thakur Shashi Pawar          male
# 1            Dheeraj Attri          male
# 2                 Moti Lal           NaN
# 3             Satpal Singh          male
# 4           Naresh Guleria        female
# ...                    ...           ...
# 20571     Amit Kumar Gupta          male
# 20572       Neelesh Bharti          male
# 20573        Deepak Dhakad           NaN
# 20574         Jagdish Jaat          male
# 20575       Manish Pradhan           NaN
#
# [20576 rows x 2 columns]

# %%
dx1=pd.read_csv('/content/First-Name-Parser.csv')

# %%
dx['First_Name']=dx1['First_Name']
# Out:
# <ipython-input-43-089f8d02b6ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dx['First_Name']=dx1['First_Name']

# %%
dx
# Out:
#           Person Full Name Person Gender First_Name
# 0      Thakur Shashi Pawar          male     thakur
# 1            Dheeraj Attri          male    dheeraj
# 2                 Moti Lal           NaN       moti
# 3             Satpal Singh          male     satpal
# 4           Naresh Guleria        female     naresh
# ...                    ...           ...        ...
# 20571     Amit Kumar Gupta          male       amit
# 20572       Neelesh Bharti          male    neelesh
# 20573        Deepak Dhakad           NaN     deepak
# 20574         Jagdish Jaat          male    jagdish
# 20575       Manish Pradhan           NaN     manish
#
# [20576 rows x 3 columns]

# %%
dx2=dx[dx['Person Gender'].isnull()]
dx2.dropna(subset=['Person Full Name'], inplace=True)
dx2
# Out:
# <ipython-input-59-97d07b9b8bd1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dx2.dropna(subset=['Person Full Name'], inplace=True)
#          Person Full Name Person Gender First_Name
# 2                Moti Lal           NaN       moti
# 9             Mlket Singh           NaN      mlket
# 13     ravinder choudhary           NaN   ravinder
# 14            sunil kumar           NaN      sunil
# 51           Vijay Sharma           NaN      vijay
# ...                   ...           ...        ...
# 20555   श्री प्रकाश  पठया           NaN   prakaash
# 20557         रोहित चौधरी           NaN      rohit
# 20566    Shri Rajeev Rana           NaN     rajeev
# 20573       Deepak Dhakad           NaN     deepak
# 20575      Manish Pradhan           NaN     manish
#
# [6616 rows x 3 columns]

# %%
import numpy as np
from tqdm.auto import tqdm

# %%
k=1
m=[]
for i in tqdm(dx2['First_Name']):
  if str(i) == 'nan' or str(i) == 'NAN':
    m.append(np.nan)
  else:
    m.append(prediction(i))
# Out:
#   0%|          | 0/6616 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# ...
# 1/1 [==============================] - 0s 21ms/step
# ...
# ...
# 1/1 [==============================] - 0s 36ms/step

# %%
set(m)
# Out:
# {'Female', 'Male', nan}

# %%
dx2['Gender_Predicted']=m
# Out:
# <ipython-input-79-da813ddd2917>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dx2['Gender_Predicted']=m

# %%
dx2
# Out:
#          Person Full Name Person Gender First_Name Gender_Predicted
# 2                Moti Lal           NaN       moti             Male
# 9             Mlket Singh           NaN      mlket           Female
# 13     ravinder choudhary           NaN   ravinder             Male
# 14            sunil kumar           NaN      sunil             Male
# 51           Vijay Sharma           NaN      vijay             Male
# ...                   ...           ...        ...              ...
# 20555   श्री प्रकाश  पठया           NaN   prakaash           Female
# 20557         रोहित चौधरी           NaN      rohit             Male
# 20566    Shri Rajeev Rana           NaN     rajeev             Male
# 20573       Deepak Dhakad           NaN     deepak             Male
# 20575      Manish Pradhan           NaN     manish             Male
#
# [6616 rows x 4 columns]

# %%
dx2.drop(['Person Gender'],axis=1,inplace=True)
# Out:
# <ipython-input-82-85eb3cd58af0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dx2.drop(['Person Gender'],axis=1,inplace=True)

# %%
dx2.to_excel('Gender_Predicted.xlsx')
