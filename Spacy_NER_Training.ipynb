# %%
#!pip install plac

# %%
from __future__ import unicode_literals, print_function
import plac
import random
from pathlib import Path
import spacy
from tqdm import tqdm

# %%
#!python -m spacy download en_core_web_lg

# %%
nlp1 = spacy.load('en_core_web_lg')

# %% [markdown]
# Working of NER

# %%
docx1=nlp1('we are going to see taj mahal')

# %%
for token in docx1.ents:
    print(token.text,token.start_char, token.end_char,token.label_)
# Out:
# taj mahal 20 29 PERSON

# %% [markdown]
# Data Preprocessing

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Spacy_NER_training_data.csv')

# %%
df['data']=df['data'].apply(lambda x:eval(x))

# %%
df['data'][0]
# Out:
# ('PRA.SHA. BHAWAN KHIRKHIRI', {'entities': [(0, 15, 'LOC')]})

# %%
TRAIN_DATA=list(df['data'])

# %%
TRAIN_DATA1 = [
    ('Who is Nishanth?', {
        'entities': [(7, 15, 'PERSON')]
    }),
     ('Who is Kamal Khumar?', {
        'entities': [(7, 19, 'PERSON')]
    }),
    ('I like London and Berlin.', {
        'entities': [(7, 13, 'LOC'), (18, 24, 'LOC')]
    })
]

# %%
model = None
#output_dir=Path("C:\\Users\\nithi\\Documents\\ner")
n_iter=4

# %%
if model is not None:
    nlp = spacy.load(model)
    print("Loaded model '%s'" % model)
else:
    nlp = spacy.blank('en')
    print("Created blank 'en' model")
# Out:
# Created blank 'en' model

# %%
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe('ner', last=True)
else:
    ner = nlp.get_pipe('ner')

# %%
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(TRAIN_DATA)
        losses = {}
        for text, annotations in tqdm(TRAIN_DATA):
          example = Example.from_dict(nlp.make_doc(text), annotations)

          nlp.update([example],drop=0.5,sgd=optimizer,losses=losses)
          #print(losses)
# Out:
# Streaming output truncated to the last 5000 lines.
#   warnings.warn(
#  77%|███████▋  | 32596/42452 [19:57<06:19, 25.95it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MA. VI. DAGARAKUAN" with entities "[(0, 8, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32599/42452 [19:57<06:31, 25.14it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "R.C.S. CONVENT SCHOOL GADAIPURA GWALIOR KA ROOM NO..." with entities "[(0, 22, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32605/42452 [19:57<06:43, 24.43it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MA SHA BHAWAN KALI PAHADI" with entities "[(0, 14, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32611/42452 [19:57<06:12, 26.39it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT.NUTAN MIDDLE SCHOOL ROOM NO.11 MANDOUR" with entities "[(0, 25, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32623/42452 [19:58<05:52, 27.86it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT.M.S.KHUTIYAVAD" with entities "[(0, 9, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32627/42452 [19:58<05:40, 28.88it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRI SCH PUKHRA" with entities "[(0, 8, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32633/42452 [19:58<05:59, 27.30it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHA. PRA. SHALA BHAWAN PACHAMA" with entities "[(0, 23, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32636/42452 [19:58<06:00, 27.24it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT. HIGHER SECONDARY SCHOOL MADHAVGANJ NO. -2 (N..." with entities "[(0, 30, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32642/42452 [19:58<06:04, 26.91it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRAA.SHA.BHAWAN PURAA" with entities "[(0, 16, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32645/42452 [19:58<06:10, 26.48it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT PRIMARY SCHOOL KACHHIYAN TOLA TIGHARA" with entities "[(0, 20, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32657/42452 [19:59<06:42, 24.35it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PANCHAYAT BHAWAN PADARIYA" with entities "[(0, 17, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRA.SHA.BHAVAN HATOD" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32663/42452 [19:59<06:27, 25.24it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "HIGHER SECONDARY SCHOOL EAST ATER" with entities "[(0, 24, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "EKIKRIT GOVT. MIDDLE SCHOOL BUILDING PROHIT PIPARI..." with entities "[(0, 37, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32669/42452 [19:59<06:37, 24.60it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY SCHOOL BUILDING NEGUVAN" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32675/42452 [20:00<07:05, 22.95it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRA.SHALA BHAVAN SALAIYAKISHOR" with entities "[(0, 17, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY SCHOOL BHAWAN GHUGHARI" with entities "[(0, 22, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT MIDDLE SCHOOL SIMRAKHURD" with entities "[(0, 19, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32681/42452 [20:00<06:33, 24.86it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRATH.SHALA UTTAR  KHAND" with entities "[(0, 12, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32687/42452 [20:00<06:28, 25.11it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY SCHOOL BUILDING KULON" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32690/42452 [20:00<06:29, 25.09it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY SCHOOL BUILDING PUTRIKHRA" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32693/42452 [20:00<06:29, 25.06it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHA PRA SHA ATI KAKSH SIRSONA" with entities "[(0, 8, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MA SHA BHAWAN PIPARA PICHOR ATI. KAKSH" with entities "[(0, 14, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32696/42452 [20:01<06:27, 25.21it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY  SCHOOL  BUILDING (NORTHERN PART )" with entities "[(0, 16, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32699/42452 [20:01<06:20, 25.64it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT. PRIMARY SCHOOL BUILDING BAGDARA" with entities "[(0, 30, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRATHAMIK SHALA BHAWAN HADABADON PASCHIMI  BHAG" with entities "[(0, 16, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32702/42452 [20:01<06:16, 25.92it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRA.SHA.BHAWAN SHRIJEE KI GANVADI" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32711/42452 [20:01<06:20, 25.62it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "HARYANTR KARYALAY PU. BHAG KOTHI NO 27 SHIVPURI" with entities "[(0, 18, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32715/42452 [20:01<06:03, 26.80it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT.P.S.SOUTH PART KARNALGANJ GUNA" with entities "[(0, 9, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32718/42452 [20:01<05:57, 27.20it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT. PRIMARY SCHOOL BUILDING BATERA" with entities "[(0, 21, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32724/42452 [20:02<05:55, 27.34it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY SCHOOL TIKAR (PARIHARIN TOLA)" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32727/42452 [20:02<06:00, 27.00it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHASKIY PRA.VI. KNAKARYA" with entities "[(0, 16, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32730/42452 [20:02<05:53, 27.47it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "shaskiy  madhyamik shala bhavan ka dakshini bhag l..." with entities "[(0, 32, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32733/42452 [20:02<05:59, 27.01it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT. PRIMARY SCHOOL BUILDING KESALA" with entities "[(0, 30, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "R C GODAM WEST" with entities "[(0, 10, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32736/42452 [20:02<06:01, 26.89it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRA. SHALA CHENTA" with entities "[(0, 11, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32739/42452 [20:02<06:14, 25.94it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY SCHOOL HRIDAYANAGAR" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "JUNIOR MIDDLE SCHOOL ‎ SHIVAPURVA TALAYAN TOLA" with entities "[(0, 21, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32742/42452 [20:02<06:10, 26.21it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "NEW GOVT MIDDLE SCHOOL BUILDING VIKRAMPUR" with entities "[(0, 23, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT.PRIMARY VIDHYALAY  SCHOOL   ATIRIKT KAKSH   C..." with entities "[(0, 31, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT.PRATHAMIK SHALA BHAWAN (ATIRIKT KAXE) JIJGOAN..." with entities "[(0, 28, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32748/42452 [20:03<06:07, 26.39it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRA.SHA.BHAWAN OCHHA" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32760/42452 [20:03<05:53, 27.44it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOURI SHANKAR PARISAR BARRAI ROOM 1" with entities "[(0, 22, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32766/42452 [20:03<05:56, 27.14it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "M.SCHOOL BHAWAN PASCHIMI PADKHURI 587" with entities "[(0, 9, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32769/42452 [20:03<06:10, 26.17it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "janpad panchayt office(new building) west room nar..." with entities "[(0, 22, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32772/42452 [20:03<06:12, 26.00it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Govt. Pra. Shala Bhawan Madwatola Kushmahar" with entities "[(0, 17, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32775/42452 [20:04<06:14, 25.84it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRATH.SHALA BAIGANIYA" with entities "[(0, 12, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32781/42452 [20:04<06:05, 26.49it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MIDDLE SCHOOL BUILDING JEVANARA" with entities "[(0, 23, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32784/42452 [20:04<06:07, 26.31it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "U0MA0VI0BAMOUR KAKSH KRA-2" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32787/42452 [20:04<06:09, 26.16it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MIDDLE SCHOOL  BUILDING SAHAJPUR ROOM NO.1" with entities "[(0, 14, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32790/42452 [20:04<06:03, 26.57it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MIDDLE SCHOOL BUILDING MANKEDI R.NO.1" with entities "[(0, 14, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHALA BHAWAN SENGUNVA" with entities "[(0, 13, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32796/42452 [20:04<05:50, 27.55it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY SCHOOL  BUILDING  SUDA" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRATH.SHALA BHAWAN  RUPAPUR" with entities "[(0, 19, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32808/42452 [20:05<05:40, 28.36it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "govt.primary school building(room no-1) kathotiya" with entities "[(0, 28, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32811/42452 [20:05<05:41, 28.22it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ADARSH PRIMARY SCHOOL RAJGADH NEAR OF TANK  CENTER..." with entities "[(0, 22, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT HIGH SCHOOL PINDARA SOUTHERN" with entities "[(0, 17, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32814/42452 [20:05<05:50, 27.49it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY SCHOOL DAIPURA" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT PRIMARY SCHOOL BUILDING KHAIRODA CHAK" with entities "[(0, 20, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT.PRIMARY SCHOOL   BUILDING  KUNKAVALI" with entities "[(0, 20, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32817/42452 [20:05<05:48, 27.62it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHA.PRA.SHA.BHAWANHIVARAHAYASING" with entities "[(0, 18, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MASIHI MIDDLE SCHOOL BUILDING EAST PART HATAPIPALY..." with entities "[(0, 30, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32821/42452 [20:05<05:35, 28.72it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GIRLS MIDDLE SCHOOL ‎ GOVINDAGADH ROOM ‎.‎NO‎.‎1‎" with entities "[(0, 20, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MIDDLE SCH MIHGUWAN" with entities "[(0, 11, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32827/42452 [20:05<05:50, 27.46it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "HR.SE. SCHOOL HINOUTI" with entities "[(0, 14, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT PRIMARY BOYS SCHOOL ADHAARTAL ROOM NO. 04" with entities "[(0, 25, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Govt Pre Secondary School Baroda Kalan" with entities "[(0, 26, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32830/42452 [20:06<05:52, 27.33it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT.MIDDLE SCHOOL  CHANDAI" with entities "[(0, 19, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32836/42452 [20:06<05:48, 27.61it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "AKIKRIT GOVT. MS ATIRIKT KAKSHA SITAPUR" with entities "[(0, 17, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT.PRIMARY SCHOOL BAKCHERA" with entities "[(0, 20, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32842/42452 [20:06<05:49, 27.50it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOMUKH GOVT.PRATHAMIK SHALA BHAWAN  PURVIBHAG KHIR..." with entities "[(0, 35, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32860/42452 [20:07<06:09, 25.99it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHASKIYA MADHYAMIK KANYA SHALA TIRODI KA POORVI BH..." with entities "[(0, 31, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "DAV SENTRAL PUBLIC SCHOOL DASAUTI" with entities "[(0, 26, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32869/42452 [20:07<05:59, 26.65it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT   PRIMARY   SCHOOL  BUILDING  BAKABHARDA" with entities "[(0, 34, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32875/42452 [20:07<05:55, 26.92it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT AGANBADI BUILDING MANGAL BHAVAN KE PAS HANUMA..." with entities "[(0, 23, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32890/42452 [20:08<05:48, 27.42it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PANCHAYAT BHAWAN IMALIYA" with entities "[(0, 17, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32893/42452 [20:08<05:42, 27.90it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MIDDLE SCHOOL BENDIPURA" with entities "[(0, 14, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  77%|███████▋  | 32899/42452 [20:08<05:43, 27.77it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PANCHAYAT BHAWAN SARO KALA" with entities "[(0, 17, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32911/42452 [20:09<05:51, 27.11it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT GIRL H.S.S. MAIHAR EASTEN" with entities "[(0, 17, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY  SCHOOL  BUILDING HINOUTA" with entities "[(0, 16, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32914/42452 [20:09<05:53, 26.98it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRA SHA BHAWAN BHILODI" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32923/42452 [20:09<05:44, 27.63it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "P.SALA BHAWAN KHAPADHANA CHUNAHUJARI" with entities "[(0, 14, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32926/42452 [20:09<05:41, 27.86it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MORASALI DHARMSHALA (PURVI BHAGA) " with entities "[(0, 20, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32929/42452 [20:09<05:40, 27.99it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "YADAV DHARMSHALA HAUL ROOM NO 1" with entities "[(0, 17, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32932/42452 [20:09<05:39, 28.05it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MANGAL BHAVANA TIKAMGARH" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32935/42452 [20:09<05:40, 27.97it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT. M.S. BADAGAON" with entities "[(0, 11, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT. P.S.NEW ADD.ROOM POONAMKHEDI" with entities "[(0, 10, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32938/42452 [20:10<05:37, 28.20it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY SCHOOL KACHHIYAN KA PURA" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32941/42452 [20:10<06:01, 26.31it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MA.SHA.BHAWAN  KACHANARIYA ROOM 1" with entities "[(0, 14, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32944/42452 [20:10<05:56, 26.64it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT PRIMARY SCHOOL PATNAKALA" with entities "[(0, 20, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32950/42452 [20:10<06:12, 25.48it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT. M.S. URDU SHALA TALAIYA MOHALLA DATIA" with entities "[(0, 22, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY SCHOOL  BUILDING DOBHI" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32956/42452 [20:10<06:13, 25.40it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT.M.S.NEW BUL.ROOM NO.4 PURANICHAVNI" with entities "[(0, 9, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32959/42452 [20:10<06:11, 25.56it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MANGAL BHAWAN PAWAI" with entities "[(0, 14, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32962/42452 [20:10<06:19, 24.98it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT MIDDLE SCHOOL  JHAKHORA" with entities "[(0, 19, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32965/42452 [20:11<06:14, 25.34it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "S.P.SHALA BHAVAN BARAYACHKHERA" with entities "[(0, 17, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32977/42452 [20:11<05:53, 26.82it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHA0PRA0VI0 BHAWAN KUI" with entities "[(0, 19, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 32992/42452 [20:12<05:37, 28.00it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Govt.Jawahar H.S.S.  Billowa Paschimi bhaag" with entities "[(0, 20, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 33004/42452 [20:12<05:58, 26.34it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MIDDLE SCHOOL BADHAPURA" with entities "[(0, 14, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 33007/42452 [20:12<06:02, 26.02it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRA. SHALA BHAWAN MAHURI" with entities "[(0, 18, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT MIDDLE SCH. ADD ROOM SIRSI" with entities "[(0, 17, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "144- PRA SHA BHAWAN JUJAWAL ROOM NO 2" with entities "[(4, 19, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 33010/42452 [20:12<06:40, 23.57it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRA.SHA.BHAWAN KANYA BILQISGANJ ROOM 1" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 33019/42452 [20:13<06:25, 24.45it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT.COMMUNITY BUILDING BARHA" with entities "[(0, 24, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "JUNIOR MIDDLE SCHOOL OUMARI" with entities "[(0, 21, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 33025/42452 [20:13<06:44, 23.28it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT MIDDLE SCH RAGUWAN" with entities "[(0, 16, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MANORANJAN BHAWAN KAHARAPURA" with entities "[(0, 18, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 33031/42452 [20:13<06:29, 24.18it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT MA VI KAMARA NO 1 PAURUKHEDI" with entities "[(0, 11, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 33037/42452 [20:13<06:11, 25.33it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PS. BUILDING BANDHI ROOM NO.2" with entities "[(0, 13, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 33040/42452 [20:14<06:00, 26.14it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY SCHOOL  BUILDING , TIKARIYA" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT.PRATHAMIK SHALA BHAWAN KADOLARAGHO" with entities "[(0, 28, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 33043/42452 [20:14<05:53, 26.58it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT.PRIMARY SCHOOL BUILDING VIKRAMPUR" with entities "[(0, 29, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  78%|███████▊  | 33061/42452 [20:14<05:48, 26.94it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHASKI PRATHMIK SHALA BHAWAN GHUNADI" with entities "[(0, 29, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...
#   warnings.warn(
# 100%|█████████▉| 42306/42452 [26:11<00:06, 23.78it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT. MIDDLE SCHOOL BUILDING BARHA" with entities "[(0, 20, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "VETERINARY HOSPITAL MUNGAOLI" with entities "[(0, 20, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42309/42452 [26:11<00:05, 23.91it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT P.S.LATHYA" with entities "[(0, 9, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42313/42452 [26:11<00:05, 25.49it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRA0SHALA0BHAVAN PALU KA PURA" with entities "[(0, 17, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "NAVIN PRA.SHALA NAYAGAV" with entities "[(0, 16, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42316/42452 [26:11<00:05, 24.91it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "BA. MAA. VI. BHATANAVAR" with entities "[(0, 13, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42340/42452 [26:12<00:04, 27.58it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PR.SHALA BHAWAN BISHONI KHURD" with entities "[(0, 16, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHA. EKIKRIT MA. SHALA BHAWAN  SALARJUN" with entities "[(0, 30, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42343/42452 [26:12<00:03, 27.33it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRAIMARI SHALA BHAWAN NAVEEN KAKSH (PURVI BHAG) GA..." with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "KANIYA P/S SCHOOL JAYNAGAR" with entities "[(0, 18, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42349/42452 [26:12<00:03, 27.14it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHASKIY GRAM PANCHYAT BHAWAN JAITPURI" with entities "[(0, 29, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42358/42452 [26:13<00:03, 24.41it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "B R B OFFICE VIKAS KHAND PARISAR" with entities "[(0, 13, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42361/42452 [26:13<00:03, 23.81it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT. MIDDLE SCHOOL  BUILDING PACHAMA" with entities "[(0, 20, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42370/42452 [26:13<00:03, 24.29it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT MIDDLE SCHOOL BULDING BELKHEDI" with entities "[(0, 27, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42373/42452 [26:13<00:03, 23.93it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHA. PRA. V. KUDRATOLA" with entities "[(0, 11, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42376/42452 [26:13<00:03, 23.04it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "NAYA PRATHAMIK SHALA BHAWAN BANIYA TOLA" with entities "[(0, 21, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT. PRIMARY SCHOOL BHAWAN ATIRIKT KAKSH UTTAR BH..." with entities "[(0, 28, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42382/42452 [26:14<00:03, 22.88it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRA.SHA.BHAWAN  CHONDI" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42394/42452 [26:14<00:02, 26.13it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT MIDDLE SCHOOL BUILDING MALIKHEDI" with entities "[(0, 19, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42397/42452 [26:14<00:02, 26.58it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRA0PATHASHALA NAYAKHENDA" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42400/42452 [26:14<00:01, 27.06it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT.PRATHAMIK SCHOOL BHAWAN PASHCHIMI KHAND MOHAN..." with entities "[(0, 29, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42406/42452 [26:15<00:01, 27.01it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRA. SHALA BHAWAN BUS STAND GHUWARA" with entities "[(0, 18, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42409/42452 [26:15<00:01, 27.12it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY SCHOOL BUILDING ANDIYA" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "E.G.S. KHATKHARI TIVARIYAN" with entities "[(0, 7, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42412/42452 [26:15<00:01, 27.64it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "HIGHER SECONDARY SCHOOL EASTERN PART PALSUD" with entities "[(0, 24, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42415/42452 [26:15<00:01, 26.80it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "JUNIOR MIDDLE SCHOOL ‎ BHUNDAHA‎" with entities "[(0, 21, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42418/42452 [26:15<00:01, 26.72it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRI. SCHOOL KACHNARA CHOTA" with entities "[(0, 12, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MA. SHA. BHAWAN ATI. KAKSH  SEVADA" with entities "[(0, 16, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42421/42452 [26:15<00:01, 26.25it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "BUNIYADI SHIKSHA SANSTHAN SIDHI PURVI BHAG" with entities "[(0, 26, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42424/42452 [26:15<00:01, 26.26it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "LAL BAHADUR SHASTRI H. S.SCHOOL PART-2" with entities "[(0, 32, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42430/42452 [26:16<00:00, 26.15it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT. PRIMARY SCHOOL BUILDING DHOKEDA" with entities "[(0, 30, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42436/42452 [26:16<00:00, 26.99it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MIDDLE SCH. MIHADAVAN" with entities "[(0, 12, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHA. PRATHAMIK SHALA BHAWANUTTARI BHAG ROSALA JAGI..." with entities "[(0, 27, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42439/42452 [26:16<00:00, 27.01it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GOVT.H S SCHOOL  JAITAVARA SOUTH" with entities "[(0, 16, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42442/42452 [26:16<00:00, 26.45it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRA.SHA.BHAWAN SAHIDAKALA" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42445/42452 [26:16<00:00, 26.38it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PANCHAYAT BHAWAN BILAHI" with entities "[(0, 17, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|█████████▉| 42448/42452 [26:16<00:00, 27.04it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PRIMARY SCHOOL KHERAHAT" with entities "[(0, 15, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|██████████| 42452/42452 [26:16<00:00, 26.92it/s]
# 100%|██████████| 42452/42452 [26:53<00:00, 26.31it/s]
# 100%|██████████| 42452/42452 [27:22<00:00, 25.84it/s]
#  99%|█████████▉| 42093/42452 [27:30<00:12, 28.36it/s]

# %%
for text, _ in TRAIN_DATA:
    doc = nlp(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Entities [('Nishanth', 'PERSON')]
# Tokens [('Who', '', 2), ('is', '', 2), ('Nishanth', 'PERSON', 3), ('?', '', 2)]
# Entities [('London', 'LOC'), ('Berlin', 'LOC')]
# Tokens [('I', '', 2), ('like', '', 2), ('London', 'LOC', 3), ('and', '', 2), ('Berlin', 'LOC', 3), ('.', '', 2)]
# Entities [('Kamal Khumar', 'PERSON')]
# Tokens [('Who', '', 2), ('is', '', 2), ('Kamal', 'PERSON', 3), ('Khumar', 'PERSON', 1), ('?', '', 2)]

# %%
docx1=nlp('PRA.SHA. BHAWAN KHIRKHIRI')
for token in docx1.ents:
    print(token.text,token.start_char, token.end_char,token.label_)
# Out:
# PRA.SHA. BHAWAN 0 15 LOC

# %%
nlp.to_disk('/content/Model')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from spacy import displacy

# %%
x=spacy.load('/content/Model')

# %%
nlp.to_pickle('/content')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-2625a00206cf> in <cell line: 1>()
# ----> 1 nlp.to_pickle('/content')
#
# AttributeError: 'English' object has no attribute 'to_pickle'

# %%
import pickle

# %%
with open('/content/model.pkl', "wb") as output_file:
    pickle.dump(nlp, output_file)

# %%
with open('/content/model.pkl', "r") as pickle_file:
    loaded_nlp = pickle.load('nlp')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-c82ac565dd84> in <cell line: 1>()
#       1 with open('/content/model.pkl', "r") as pickle_file:
# ----> 2     loaded_nlp = pickle.load('nlp')
#
# TypeError: file must have 'read' and 'readline' attributes

# %%
import zipfile
import os
import shutil

# %%
folder_to_zip = '/content/Model'

# Define the zip filename
zip_filename = 'Spacy_NER.zip'

# %%
shutil.make_archive(zip_filename.replace('.zip', ''), 'zip', folder_to_zip)
# Out:
# '/content/Spacy_NER.zip'
